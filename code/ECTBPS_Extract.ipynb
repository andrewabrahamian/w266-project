# %% [markdown]
# # Basic Installation

# %%
# %cd /content/
# %rm -rf /content/ECTSum/
# %cd /content/
# Out:
# /content
# /content

# %%
#Clone ECTSUM Repo
# !git clone https://RajdeepMukherjee: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@github.com/rajdeep345/ECTSum.git
# Out:
# Cloning into 'ECTSum'...
# remote: Enumerating objects: 16499, done.
# remote: Counting objects: 100% (1265/1265), done.
# remote: Compressing objects: 100% (822/822), done.
# remote: Total 16499 (delta 507), reused 978 (delta 425), pack-reused 15234
# Receiving objects: 100% (16499/16499), 26.45 MiB | 20.96 MiB/s, done.
# Resolving deltas: 100% (6924/6924), done.
# Updating files: 100% (16592/16592), done.

# %%
#Connect to Google Drive
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#https://drive.google.com/drive/folders/1eEYgfs8BhfcysM0Kq2D_EshOZTowlHQL?usp=drive_link

# %%
#Examine MyDrive Directory
# !ls drive/MyDrive/w266-project/ -l
# Out:
# total 447331
# -rw------- 1 root root     12988 Jul  7 20:09 ECTBPS_Extract.ipynb
# -rw------- 1 root root   7854547 Jul  1 01:39 ECTBPS_Paraphrase.ipynb
# drwx------ 2 root root      4096 Jun  7 01:04 lit-review
# drwx------ 3 root root      4096 Jun 23 00:24 new_data
# drwx------ 2 root root      4096 Jul  7 18:09 outputs_ext
# -rw------- 1 root root      9232 Jul  7 20:09 process_newdata.ipynb
# -rw------- 1 root root 450175363 Jul  6 21:47 RNN_RNN_seed_43.pt
# -rw------- 1 root root       182 Jul  7 00:49 w266-meeting-notes.gdoc
# -rw------- 1 root root       182 Jul  5 23:07 w266-project-proposal-andrewabrahamian-theresa-azinge.gdoc

# %%
#Examine ECTSum Directory
# !ls ECTSum -l
# Out:
# total 68
# drwxr-xr-x 4 root root  4096 Jul  7 20:10 codes
# drwxr-xr-x 3 root root  4096 Jul  7 20:10 data
# -rw-r--r-- 1 root root  6057 Jul  7 20:10 evaluate.py
# -rw-r--r-- 1 root root  6703 Jul  7 20:10 evaluate_with_mask.py
# -rw-r--r-- 1 root root  6022 Jul  7 20:10 prepare_data_ectbps_ext.py
# -rw-r--r-- 1 root root  3002 Jul  7 20:10 prepare_data_ectbps_para_mask.py
# -rw-r--r-- 1 root root  4672 Jul  7 20:10 prepare_data_ectbps_para.py
# drwxr-xr-x 2 root root  4096 Jul  7 20:10 __pycache__
# -rw-r--r-- 1 root root  2321 Jul  7 20:10 README.md
# -rw-r--r-- 1 root root 13418 Jul  7 20:10 utils.py

# %% [markdown]
# # Imports & Configurations

# %%
# %%capture
# !pip install simpletransformers
# !pip install num2words
# !pip install word2number

# %%
import random
import warnings
import numpy as np
import logging
from datetime import datetime
from num2words import num2words
from word2number import w2n

from simpletransformers.seq2seq import Seq2SeqModel, Seq2SeqArgs

logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("t5_paraphrase")
transformers_logger.setLevel(logging.ERROR)

import os
import pandas as pd

# %% [markdown]
# # Download latest ECTBPS Extractive Model model

# %%
#Change to ECTSum/codes
# %cd ECTSum/codes/ECT-BPS/ectbps_ext
#!pwd
# Out:
# /content/ECTSum/codes/ECT-BPS/ectbps_ext

# %%
# !pip install tensorrt

# %%
# DO NOT USE
# TRAIN THE MODEL FOR 4 EPOCH
#!python main.py -batch_size 1 -acc_steps 4 -epochs 4 -model RNN_RNN -seed 43

# %%
#copy model checkpoint to newly-created checkpoints subfolder
os.mkdir('checkpoints')
# %cp /content/drive/MyDrive/w266-project/RNN_RNN_seed_43.pt checkpoints

# %%
# LOAD PRE-TRAINED MODEL
# !python main.py -test -batch_size 1 -load_dir checkpoints/RNN_RNN_seed_43.pt
# Out:
# 2023-07-07 20:11:04.754991: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-07 20:11:06,805 [INFO] TESTING
# Some weights of the model checkpoint at ProsusAI/finbert were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100% 495/495 [00:55<00:00,  8.89it/s]
# 2023-07-07 20:12:12,074 [INFO] Speed: 13.067651051085958 docs / s

# %% [markdown]
# # Run Model on New Q&A Data

# %%
os.mkdir("new_data")
# %cp /content/drive/MyDrive/w266-project/new_data/final/final/*.txt new_data #-r

# %%
dir = 'new_data'
files = os.listdir(dir)

for file in files:
  file_path = os.path.join(dir,file)
  # !python main.py -predict -filename '{file_path}' -batch_size 1 -load_dir checkpoints/RNN_RNN_seed_43.pt
# Out:
# 2023-07-07 20:19:42.685388: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-07 20:19:44,722 [INFO] PREDICTING
# Some weights of the model checkpoint at ProsusAI/finbert were not used when initializing BertModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 100% 1/1 [00:00<00:00,  4.22it/s]
# 2023-07-07 20:19:50,249 [INFO] Speed: 4.9868904461718815 docs / s
# 2023-07-07 20:19:56.416138: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
#!python main.py -predict -filename 'new_data/2016-Apr-20-ASML.txt' -batch_size 1 -load_dir checkpoints/RNN_RNN_seed_43.pt

# %%
#os.mkdir('/content/drive/MyDrive/w266-project/outputs_ext')
# %cp outputs/hyp/20*.txt /content/drive/MyDrive/w266-project/outputs_ext

# %% [markdown]
# #Test Performance of Extractive Model on SUPERT Reference Summaries

# %%
def getPredData(dataPath):
  predPath = f'dataPath'
  testFiles = [file for file in os.listdir(dataPath)]
  PredData = []
  for file in sorted(testFiles):
    dataset = []
    doc_in = open(f'{dataPath}/{file}', 'r', encoding='utf8')
    doc_lines = [line.strip() for line in doc_in.readlines()]
    for line in doc_lines:
      text_to_paraphrase = line.strip().lower()
      dataset.append(text_to_paraphrase)
    PredData.append('\n'.join(dataset) + '\n')

  return PredData

# %%
extPath = '/content/drive/MyDrive/w266-project/supert/outputs_ext'
ext_summaries = getPredData(extPath)

pseudoPath = '/content/drive/MyDrive/w266-project/supert/ref_summaries'
pseudo_refs = getPredData(pseudoPath)

# %%
print(ext_summaries[0])
print(pseudo_refs[0])
# Out:
# and then with these actions that we're taking, when we get to full realization, and i want to stress, we do believe that this will give us an opportunity to reinvest in the business and actually accelerate growth, but if you just look at the cost side of it, it's 2 to 3 points of spending as a percent of revenue when we get to mid-2017, and full realization. that takes our spending as a percent of revenue, even just based on your estimate of 2016 revenue, it's 2 to 3 points, it takes us back down into the low 30s from a spending as percent of revenue. you can do the math from there and see what we think we can achieve next year in terms of overall operating range.
# ...

# %%
# !pip install evaluate rouge_score
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 2.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.1/519.1 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 19.9 MB/s eta 0:00:00
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=b2510cf6432c1dd54210f5a036ed16aa3bcaffb9661731b4cc247a376c0ed6e6
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# ...

# %%
import evaluate

rouge = evaluate.load("rouge")

# %%
def getScores(dataset1, dataset2):
  scores = []
  for i in range(len(dataset1)):
    scores1 = rouge.compute(
        predictions=[dataset1[i]], references=[dataset2[i]]
        )
    scores.append(scores1)
  rouge1 = []
  rouge2 = []
  rougeL = []
  rougeLsum = []
  for i in range(len(scores)):
    rouge1.append(scores[i]['rouge1'])
    rouge2.append(scores[i]['rouge2'])
    rougeL.append(scores[i]['rougeL'])
    rougeLsum.append(scores[i]['rougeLsum'])

  rouge1Avg = sum(rouge1) / len(rouge1)
  rouge2Avg = sum(rouge2) / len(rouge2)
  rougeLAvg = sum(rougeL) / len(rougeL)
  rougeLsumAvg = sum(rougeLsum) / len(rougeLsum)
  return 'rouge 1 Avg', rouge1Avg, 'rouge 2 Avg', rouge2Avg, 'rouge L Avg', rougeLAvg, 'rouge LSum Avg', rougeLsumAvg

# %%
rougeExt = getScores(pseudo_refs, ext_summaries)

# %%
rougeExt
# Out:
# ('rouge 1 Avg',
#  0.43399099324060025,
#  'rouge 2 Avg',
#  0.2363794262573054,
#  'rouge L Avg',
#  0.18853315736356985,
#  'rouge LSum Avg',
#  0.41167047218260194)

# %%
# !pip install bert_score
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 62.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 87.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.1 MB/s eta 0:00:00
# ...

# %%
from evaluate import load
bertscore = load("bertscore")
results = bertscore.compute(predictions=ext_summaries, references=pseudo_refs, lang="en")
# Out:
# ...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print('The average precision is', sum(results['precision'])/len(results['precision']), '\nThe average recall is', sum(results['recall'])/len(results['recall']), '\nThe average F1 score is', sum(results['f1'])/len(results['f1']))
# Out:
# The average precision is 0.8469916048285725
# The average recall is 0.8413378707655184
# The average F1 score is 0.8441167644092015
